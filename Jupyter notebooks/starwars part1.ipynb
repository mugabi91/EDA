# %% [markdown]
# # STAR WARS  DATASET

# %% [markdown]
# Introduction to the Star Wars Franchise Dataset:
#
# The Star Wars franchise is one of the most iconic and beloved series in the history of popular culture. It encompasses a vast universe filled with memorable characters, epic battles, and intricate lore. For those unfamiliar with the franchise, Star Wars began as a groundbreaking film created by George Lucas in 1977, titled "Star Wars: Episode IV - A New Hope". Since then, it has expanded into a multimedia phenomenon, including movies, TV shows, books, comics, video games, and more.
#
# The Star Wars franchise dataset provides a comprehensive collection of data related to various aspects of this expansive universe. It includes information about characters, planets, starships, vehicles, species, and much more. This dataset offers valuable insights into the rich tapestry of the Star Wars universe, allowing fans and researchers alike to explore and analyze different elements of the franchise.
#
# Whether you're interested in learning about the iconic characters like Luke Skywalker, Princess Leia, and Darth Vader, or delving into the details of planets like Tatooine, Endor, and Coruscant, the Star Wars dataset offers a treasure trove of information waiting to be discovered. From lightsaber duels to space battles, from the Force to the Dark Side, the Star Wars franchise dataset invites you to embark on an exciting journey through a galaxy far, far away. May the Force be with you as you explore this fascinating dataset!

# %% [markdown]
# importing necessary imports for now

# %%
# importing modules 
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

# %% [markdown]
# Reading in data into  memory

# %%
#reading data 
path = r"C:\Users\M D\Desktop\archive\star-wars-survey-data\star_wars.csv"
df = pd.read_csv(path)
df.head(2)
# Out:
#    RespondentID Have you seen any of the 6 films in the Star Wars franchise?  \
# 0           NaN                                           Response
# 1  3.292880e+09                                                Yes
#
#   Do you consider yourself to be a fan of the Star Wars film franchise?  \
# 0                                           Response
# 1                                                Yes
#
#   Which of the following Star Wars films have you seen? Please select all that apply.  \
# 0           Star Wars: Episode I  The Phantom Menace
# 1           Star Wars: Episode I  The Phantom Menace
#
#                                     Unnamed: 4  \
# 0  Star Wars: Episode II  Attack of the Clones
# 1  Star Wars: Episode II  Attack of the Clones
#
#                                     Unnamed: 5  \
# 0  Star Wars: Episode III  Revenge of the Sith
# 1  Star Wars: Episode III  Revenge of the Sith
#
#                           Unnamed: 6  \
# 0  Star Wars: Episode IV  A New Hope
# 1  Star Wars: Episode IV  A New Hope
#
#                                      Unnamed: 7  \
# 0  Star Wars: Episode V The Empire Strikes Back
# 1  Star Wars: Episode V The Empire Strikes Back
#
#                                  Unnamed: 8  \
# 0  Star Wars: Episode VI Return of the Jedi
# 1  Star Wars: Episode VI Return of the Jedi
#
#   Please rank the Star Wars films in order of preference with 1 being your favorite film in the franchise and 6 being your least favorite film.  \
# 0           Star Wars: Episode I  The Phantom Menace
# 1                                                  3
#
#    ...     Unnamed: 28       Which character shot first?  \
# 0  ...            Yoda                          Response
# 1  ...  Very favorably  I don't understand this question
#
#   Are you familiar with the Expanded Universe?  \
# 0                                     Response
# 1                                          Yes
#
#   Do you consider yourself to be a fan of the Expanded Universe?æ  \
# 0                                           Response
# 1                                                 No
#
#   Do you consider yourself to be a fan of the Star Trek franchise?    Gender  \
# 0                                           Response                Response
# 1                                                 No                    Male
#
#         Age Household Income           Education Location (Census Region)
# 0  Response         Response            Response                 Response
# 1     18-29              NaN  High school degree           South Atlantic
#
# [2 rows x 38 columns]

# %% [markdown]
# ## Exploring the Data set

# %% [markdown]
# Finding out the size of the dataset (rows ,variables/columns) and dropping any duplicate entries if any exist

# %%
df.drop_duplicates()
df.shape
# Out:
# (1187, 38)

# %% [markdown]
# Getting the information on the columns/variables in the dataset and data types in each

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1187 entries, 0 to 1186
# Data columns (total 38 columns):
#  #   Column                                                                                                                                         Non-Null Count  Dtype
# ---  ------                                                                                                                                         --------------  -----
#  0   RespondentID                                                                                                                                   1186 non-null   float64
#  1   Have you seen any of the 6 films in the Star Wars franchise?                                                                                   1187 non-null   object
#  2   Do you consider yourself to be a fan of the Star Wars film franchise?                                                                          837 non-null    object
#  3   Which of the following Star Wars films have you seen? Please select all that apply.                                                            674 non-null    object
#  4   Unnamed: 4                                                                                                                                     572 non-null    object
#  5   Unnamed: 5                                                                                                                                     551 non-null    object
#  6   Unnamed: 6                                                                                                                                     608 non-null    object
#  7   Unnamed: 7                                                                                                                                     759 non-null    object
#  8   Unnamed: 8                                                                                                                                     739 non-null    object
#  9   Please rank the Star Wars films in order of preference with 1 being your favorite film in the franchise and 6 being your least favorite film.  836 non-null    object
#  10  Unnamed: 10                                                                                                                                    837 non-null    object
#  11  Unnamed: 11                                                                                                                                    836 non-null    object
#  12  Unnamed: 12                                                                                                                                    837 non-null    object
#  13  Unnamed: 13                                                                                                                                    837 non-null    object
#  14  Unnamed: 14                                                                                                                                    837 non-null    object
#  15  Please state whether you view the following characters favorably, unfavorably, or are unfamiliar with him/her.                                 830 non-null    object
#  16  Unnamed: 16                                                                                                                                    832 non-null    object
#  17  Unnamed: 17                                                                                                                                    832 non-null    object
#  18  Unnamed: 18                                                                                                                                    824 non-null    object
#  19  Unnamed: 19                                                                                                                                    826 non-null    object
#  20  Unnamed: 20                                                                                                                                    815 non-null    object
#  21  Unnamed: 21                                                                                                                                    827 non-null    object
#  22  Unnamed: 22                                                                                                                                    821 non-null    object
#  23  Unnamed: 23                                                                                                                                    813 non-null    object
#  24  Unnamed: 24                                                                                                                                    828 non-null    object
#  25  Unnamed: 25                                                                                                                                    831 non-null    object
#  26  Unnamed: 26                                                                                                                                    822 non-null    object
#  27  Unnamed: 27                                                                                                                                    815 non-null    object
#  28  Unnamed: 28                                                                                                                                    827 non-null    object
#  29  Which character shot first?                                                                                                                    829 non-null    object
#  30  Are you familiar with the Expanded Universe?                                                                                                   829 non-null    object
#  31  Do you consider yourself to be a fan of the Expanded Universe?æ                                                                               214 non-null    object
#  32  Do you consider yourself to be a fan of the Star Trek franchise?                                                                               1069 non-null   object
#  33  Gender                                                                                                                                         1047 non-null   object
#  34  Age                                                                                                                                            1047 non-null   object
#  35  Household Income                                                                                                                               859 non-null    object
#  36  Education                                                                                                                                      1037 non-null   object
#  37  Location (Census Region)                                                                                                                       1044 non-null   object
# dtypes: float64(1), object(37)
# memory usage: 352.5+ KB

# %% [markdown]
# As seen above the  variable names are too long and they need to be renamed..
#
# some columns are unnecessary and need to go .

# %% [markdown]
# ### Dropping the unnecessary columns

# %%
df.drop(['Unnamed: 4','Unnamed: 5','Unnamed: 6','Unnamed: 7','Unnamed: 8','Unnamed: 10','Unnamed: 11','Unnamed: 12','Unnamed: 13','Unnamed: 14',
         'Unnamed: 16','Unnamed: 17','Unnamed: 18','Unnamed: 20','Unnamed: 19','Unnamed: 20','Unnamed: 21','Unnamed: 22','Unnamed: 23','Unnamed: 24','Unnamed: 25',
         'Unnamed: 26','Unnamed: 27','Unnamed: 28'],axis=1,inplace=True)

# %%
ro, wi = df.shape
total_slots = ro*wi
total_slots
# Out:
# 17805

# %% [markdown]
# left columns after dropping the unnecessary ones

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1187 entries, 0 to 1186
# Data columns (total 15 columns):
#  #   Column                                                                                                                                         Non-Null Count  Dtype
# ---  ------                                                                                                                                         --------------  -----
#  0   RespondentID                                                                                                                                   1186 non-null   float64
#  1   Have you seen any of the 6 films in the Star Wars franchise?                                                                                   1187 non-null   object
#  2   Do you consider yourself to be a fan of the Star Wars film franchise?                                                                          837 non-null    object
#  3   Which of the following Star Wars films have you seen? Please select all that apply.                                                            674 non-null    object
#  4   Please rank the Star Wars films in order of preference with 1 being your favorite film in the franchise and 6 being your least favorite film.  836 non-null    object
#  5   Please state whether you view the following characters favorably, unfavorably, or are unfamiliar with him/her.                                 830 non-null    object
#  6   Which character shot first?                                                                                                                    829 non-null    object
#  7   Are you familiar with the Expanded Universe?                                                                                                   829 non-null    object
#  8   Do you consider yourself to be a fan of the Expanded Universe?æ                                                                               214 non-null    object
#  9   Do you consider yourself to be a fan of the Star Trek franchise?                                                                               1069 non-null   object
#  10  Gender                                                                                                                                         1047 non-null   object
#  11  Age                                                                                                                                            1047 non-null   object
#  12  Household Income                                                                                                                               859 non-null    object
#  13  Education                                                                                                                                      1037 non-null   object
#  14  Location (Census Region)                                                                                                                       1044 non-null   object
# dtypes: float64(1), object(14)
# memory usage: 139.2+ KB

# %% [markdown]
# we have 15 left over columns after dropping all the unnecessary columns all the way from 37 of them

# %% [markdown]
# ### Renaming columns

# %%
df.rename(columns={
      'Have you seen any of the 6 films in the Star Wars franchise?':"watched_starwars",
 'Do you consider yourself to be a fan of the Star Wars film franchise?':"starwars_fan",
 'Which of the following Star Wars films have you seen? Please select all that apply.':'watched_starwars_films',
 'Please rank the Star Wars films in order of preference with 1 being your favorite film in the franchise and 6 being your least favorite film.':'ranking',
 'Please state whether you view the following characters favorably, unfavorably, or are unfamiliar with him/her.':"taste_character",
 'Which character shot first?':'fired_first',
 'Are you familiar with the Expanded Universe?':'knowledge_of_expanded_universe',
 'Do you consider yourself to be a fan of the Expanded Universe?æ':'Expanded_universe_fan',
 'Do you consider yourself to be a fan of the Star Trek franchise?':'star_trek_fan',
 'Location (Census Region)':"Location",
    
    
},inplace=True)

# %% [markdown]
# A look at the new renamed column names  and dtypes(data types)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1187 entries, 0 to 1186
# Data columns (total 15 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   RespondentID                    1186 non-null   float64
#  1   watched_starwars                1187 non-null   object
#  2   starwars_fan                    837 non-null    object
#  3   watched_starwars_films          674 non-null    object
#  4   ranking                         836 non-null    object
#  5   taste_character                 830 non-null    object
#  6   fired_first                     829 non-null    object
#  7   knowledge_of_expanded_universe  829 non-null    object
#  8   Expanded_universe_fan           214 non-null    object
#  9   star_trek_fan                   1069 non-null   object
#  10  Gender                          1047 non-null   object
#  11  Age                             1047 non-null   object
#  12  Household Income                859 non-null    object
#  13  Education                       1037 non-null   object
#  14  Location                        1044 non-null   object
# dtypes: float64(1), object(14)
# memory usage: 139.2+ KB

# %% [markdown]
# ###

# %% [markdown]
# Before data types are changed . There is need to know what really is in these columns to prevent conversion errors

# %% [markdown]
# checking for the null entry totals for each column

# %%
total_nulls = df.isna().sum().reset_index()
total_nulls.columns = ['Variable','Null_total']
total_nulls
# Out:
#                           Variable  Null_total
# 0                     RespondentID           1
# 1                 watched_starwars           0
# 2                     starwars_fan         350
# 3           watched_starwars_films         513
# 4                          ranking         351
# 5                  taste_character         357
# 6                      fired_first         358
# 7   knowledge_of_expanded_universe         358
# 8            Expanded_universe_fan         973
# 9                    star_trek_fan         118
# 10                          Gender         140
# 11                             Age         140
# 12                Household Income         328
# 13                       Education         150
# 14                        Location         143

# %%
loss_percentage =  (np.sum(total_nulls["Null_total"])/total_slots)*100
print(f"{loss_percentage:.2f}% of the data will be lost if all nulls are dropped" )
# Out:
# 24.04% of the data will be lost if all nulls are dropped

# %% [markdown]
# There is too much data to be  lost if all nulls are dropped
# Therefore we are not dropping but to impute as best as we can

# %% [markdown]
# ### Understanding what the columns exactly contain

# %%
columns = [feature for feature in df.columns if feature != "RespondentID"] 
columns
# Out:
# ['watched_starwars',
#  'starwars_fan',
#  'watched_starwars_films',
#  'ranking',
#  'taste_character',
#  'fired_first',
#  'knowledge_of_expanded_universe',
#  'Expanded_universe_fan',
#  'star_trek_fan',
#  'Gender',
#  'Age',
#  'Household Income',
#  'Education',
#  'Location']

# %%
for col in columns:
    print(f"{col}")
    print(f"{df[col].unique()}\n")
# Out:
# watched_starwars
# ['Response' 'Yes' 'No']
#
# starwars_fan
# ['Response' 'Yes' nan 'No']
#
# watched_starwars_films
# ['Star Wars: Episode I  The Phantom Menace' nan]
#
# ranking
# ['Star Wars: Episode I  The Phantom Menace' '3' nan '1' '5' '6' '4' '2']
#
# taste_character
# ['Han Solo' 'Very favorably' nan 'Somewhat favorably'
#  'Neither favorably nor unfavorably (neutral)' 'Somewhat unfavorably'
#  'Unfamiliar (N/A)' 'Very unfavorably']
#
# fired_first
# ['Response' "I don't understand this question" nan 'Greedo' 'Han']
#
# knowledge_of_expanded_universe
# ['Response' 'Yes' nan 'No']
#
# Expanded_universe_fan
# ['Response' 'No' nan 'Yes']
#
# star_trek_fan
# ['Response' 'No' 'Yes' nan]
#
# Gender
# ['Response' 'Male' nan 'Female']
#
# Age
# ['Response' '18-29' nan '30-44' '> 60' '45-60']
#
# Household Income
# ['Response' nan '$0 - $24,999' '$100,000 - $149,999' '$25,000 - $49,999'
#  '$50,000 - $99,999' '$150,000+']
#
# Education
# ['Response' 'High school degree' 'Bachelor degree'
#  'Some college or Associate degree' nan 'Graduate degree'
#  'Less than high school degree']
#
# Location
# ['Response' 'South Atlantic' 'West South Central' 'West North Central'
#  'Middle Atlantic' 'East North Central' 'Pacific' nan 'Mountain'
#  'New England' 'East South Central']

# %% [markdown]
# #### Converting dtypes

# %%
df.drop(df[df['RespondentID'].isna()].index,inplace=True)
df.reset_index(drop=True,inplace=True)
df['RespondentID'] = pd.to_numeric(df['RespondentID'],errors="coerce")
df['RespondentID'] = df['RespondentID'].astype(object)
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1186 entries, 0 to 1185
# Data columns (total 15 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   RespondentID                    1186 non-null   object
#  1   watched_starwars                1186 non-null   object
#  2   starwars_fan                    836 non-null    object
#  3   watched_starwars_films          673 non-null    object
#  4   ranking                         835 non-null    object
#  5   taste_character                 829 non-null    object
#  6   fired_first                     828 non-null    object
#  7   knowledge_of_expanded_universe  828 non-null    object
#  8   Expanded_universe_fan           213 non-null    object
#  9   star_trek_fan                   1068 non-null   object
#  10  Gender                          1046 non-null   object
#  11  Age                             1046 non-null   object
#  12  Household Income                858 non-null    object
#  13  Education                       1036 non-null   object
#  14  Location                        1043 non-null   object
# dtypes: object(15)
# memory usage: 139.1+ KB

# %%
for col in columns:
    df[col] = df[col].astype("category")
    
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1186 entries, 0 to 1185
# Data columns (total 15 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   RespondentID                    1186 non-null   object
#  1   watched_starwars                1186 non-null   category
#  2   starwars_fan                    836 non-null    category
#  3   watched_starwars_films          673 non-null    category
#  4   ranking                         835 non-null    category
#  5   taste_character                 829 non-null    category
#  6   fired_first                     828 non-null    category
#  7   knowledge_of_expanded_universe  828 non-null    category
#  8   Expanded_universe_fan           213 non-null    category
#  9   star_trek_fan                   1068 non-null   category
#  10  Gender                          1046 non-null   category
#  11  Age                             1046 non-null   category
#  12  Household Income                858 non-null    category
#  13  Education                       1036 non-null   category
#  14  Location                        1043 non-null   category
# dtypes: category(14), object(1)
# memory usage: 28.0+ KB

# %% [markdown]
# # VISUALS

# %% [markdown]
# ### What is the make up of the fans by franchise ?

# %%
sns.set_theme(style='darkgrid')
sns.set_palette('Accent')


categories = ['starwars_fan', 'star_trek_fan', 'Expanded_universe_fan']
titles = ['Number of Star Wars fans', 'Number of Star Trek fans', 'Number of Expanded Universe fans']


fig, axes = plt.subplots(3, 3, figsize=(15, 12))


for i, (category, title) in enumerate(zip(categories, titles)):
    sns.countplot(data=df, x=category, ax=axes[i, 0])
    axes[i, 0].set_title(title.upper())
    
    sns.countplot(data=df, hue=category, x='Gender', ax=axes[i, 1])
    axes[i, 1].set_title(f'by Gender for {title}'.upper())
    
    sns.countplot(data=df, hue=category, x='Age', ax=axes[i, 2])
    axes[i, 2].set_title(f'by Age for {title}'.upper())


plt.tight_layout()
plt.show()

# %% [markdown]
# ### INSIGHTS

# %% [markdown]
# As seen above starwars has got the highest number of fans followed by star trek and last the expanded universe
#
# The fan make up by gender shows its mostly Males interested in the franchises
#
# For starwars it has mostly a fan base of people aged 30 to 60 yrs of age
#
# For star_trek, it has mostly a fan base of people 45 to 60 yrs of age
#
# For the expanded universe, it has a fan base mainly of younger people of ages 18 to 44 yrs
#
# Looking at the female fan base of all the franchises, starwars has the highest female base compared to the others. star trek comes in second and the expanded universe comes in last
#
# Looking at the male fan base of all the franchises, starwars has the highest male fan base compared to the others. star trek comes in second and the expanded universe comes in last

# %% [markdown]
# ### Where are most fans from ?

# %%
fig,ax =plt.subplots(4,1, figsize=(15,15))

sns.countplot(data=df, x="Location",ax=ax[0])
ax[0].set_title("fans location".upper())

sns.countplot(data=df, x="Location",hue="starwars_fan",ax=ax[1])
ax[1].set_title("starwars fans Location".upper())

sns.countplot(data=df, x="Location", hue="star_trek_fan",ax=ax[2])
ax[2].set_title("star trek fans location".upper())

sns.countplot(data=df, x="Location", hue="Expanded_universe_fan",ax=ax[3])
ax[3].set_title("Expanded universe fans location".upper())

plt.tight_layout()
plt.show()

# %% [markdown]
# ### What are the income and Education levels of the FAN bases?

# %%
categories = ['starwars_fan', 'star_trek_fan', 'Expanded_universe_fan']
titles = [' levels of Star Wars fans', 'levels Star Trek fans', ' levels of Expanded Universe fans']


fig, axes = plt.subplots(3, 2, figsize=(15, 15))



for i, (category, title) in enumerate(zip(categories, titles)):
 
    sns.countplot(data=df, hue=category, x='Household Income', ax=axes[i, 0])
    axes[i, 0].set_title(f' income {title}'.upper())
    
    sns.countplot(data=df, hue=category, x='Education', ax=axes[i, 1])
    axes[i, 1].set_title(f'Education  {title}'.upper())
    axes[i, 1].tick_params(axis='x', rotation=45)


plt.tight_layout()
plt.show()
